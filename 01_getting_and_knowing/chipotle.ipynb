# %% [markdown]
# # Chipotle

# %%
import pandas as pd

# %% [markdown]
# # let us import the data via url

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
chipotle = pd.read_csv(url, sep = '\t')

# %%
chipotle
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# ...

# %%
chipotle.head(100)
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 1          1         1                                   Izze
# 2          1         1                       Nantucket Nectar
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
# 11         6         1                   Chicken Crispy Tacos
# 12         6         1                     Chicken Soft Tacos
# 13         7         1                           Chicken Bowl
# ...

# %% [markdown]
# # check for observations :

# %%
chipotle.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
chipotle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
# order_id              4622 non-null int64
# quantity              4622 non-null int64
# item_name             4622 non-null object
# choice_description    3376 non-null object
# item_price            4622 non-null object
# dtypes: int64(2), object(3)
# memory usage: 180.6+ KB

# %%
chipotle['item_name'].nunique()
# Out:
# 50

# %% [markdown]
# # Step 6. What is the number of columns in the dataset?

# %%
chipotle.shape
# Out:
# (4622, 5)

# %% [markdown]
# # Step 7. Print the name of all the columns.¶

# %%
chipotle.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# # Step 8. How is the dataset indexed?

# %%
chipotle.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# # Step 9. Which was the most ordered item?

# %%
chipotle.item_name.value_counts()
# Out:
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chips and Guacamole                      479
# Steak Burrito                            368
# Canned Soft Drink                        301
# Steak Bowl                               211
# Chips                                    211
# Bottled Water                            162
# Chicken Soft Tacos                       115
# Chicken Salad Bowl                       110
# Chips and Fresh Tomato Salsa             110
# Canned Soda                              104
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          91
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             66
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# ...

# %%
chipotle.groupby('item_name').agg({'item_name': 'count'}).sort_values('item_name', ascending = False)
# Out:
#                                        item_name
# item_name
# Chicken Bowl                                 726
# Chicken Burrito                              553
# Chips and Guacamole                          479
# Steak Burrito                                368
# Canned Soft Drink                            301
# Steak Bowl                                   211
# Chips                                        211
# Bottled Water                                162
# Chicken Soft Tacos                           115
# Chicken Salad Bowl                           110
# Chips and Fresh Tomato Salsa                 110
# Canned Soda                                  104
# Side of Chips                                101
# Veggie Burrito                                95
# Barbacoa Burrito                              91
# Veggie Bowl                                   85
# Carnitas Bowl                                 68
# Barbacoa Bowl                                 66
# ...

# %% [markdown]
# # Step 10. How many items were ordered?

# %%
order_count = chipotle.groupby('item_name').agg({'item_name': 'count'}).sort_values('item_name', ascending = False)
order_count['item_name'].max()
# Out:
# 726

# %% [markdown]
# # Step 11. What was the most ordered item in the choice_description column?

# %%
chipotle.choice_description.value_counts()
# Out:
# [Diet Coke]                                                                                                                                                     134
# [Coke]                                                                                                                                                          123
# [Sprite]                                                                                                                                                         77
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]                                                                                           42
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]                                                                                40
# [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice, Cheese, Sour Cream]]                                                                                             36
# ...

# %% [markdown]
# # Step 12. How many items were orderd in total?

# %%
chipotle.quantity.sum()
# Out:
# 4972

# %% [markdown]
# # Step 13. Turn the item price into a float

# %%
dollarizer = lambda x: float(x[1:-1])
chipotle.item_price = chipotle.item_price.apply(dollarizer)

# %% [markdown]
# # Step 14. How much was the revenue for the period in the dataset?¶

# %%
chipotle.item_price.sum()
# Out:
# 34500.16000000046

# %% [markdown]
# # Step 15. How many orders were made in the period?

# %%
chipotle.order_id.nunique()
# Out:
# 1834

# %% [markdown]
# # Step 16. What is the average amount per order?

# %%
chipotle.item_price.sum() / chipotle.order_id.nunique()
# Out:
# 18.811428571428824

# %%
order_grouped = chipotle.groupby(by=['order_id']).sum().mean()

# %%
order_grouped
# Out:
# quantity       2.711014
# item_price    18.811429
# dtype: float64

# %% [markdown]
# # Step 17. How many different items are sold?

# %%
chipotle.item_name.nunique()
# Out:
# 50
